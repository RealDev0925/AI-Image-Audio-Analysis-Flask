# %%
from deepgram import Deepgram
import json

# The API key we created in step 3
DEEPGRAM_API_KEY = '7e70e6a5a41d1888c0e0ebe57caa3f748a2d9072'

# Hosted sample file
AUDIO_URL = "https://static.deepgram.com/examples/Bueller-Life-moves-pretty-fast.wav"

def main():
    # Initializes the Deepgram SDK
    dg_client = Deepgram(DEEPGRAM_API_KEY)
    source = {'url': AUDIO_URL}
    options = { "smart_format": True, "model": "nova-2", "language": "en-US" }

    print('Requesting transcript...')
    print('Your file may take up to a couple minutes to process.')
    print('While you wait, did you know that Deepgram accepts over 40 audio file formats? Even MP4s.')
    print('To learn more about customizing your transcripts check out developers.deepgram.com')

    response = dg_client.transcription.sync_prerecorded(source, options)
    print(json.dumps(response, indent=4))

main()
# Out:
# Requesting transcript...
# Your file may take up to a couple minutes to process.
# While you wait, did you know that Deepgram accepts over 40 audio file formats? Even MP4s.
# To learn more about customizing your transcripts check out developers.deepgram.com
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
# ...

# %%
import requests

# URL and endpoint
url = "https://api.deepgram.com/v1/listen?smart_format=true&punctuate=true&filler_words=true&language=en&model=nova-2"

# Headers
headers = {
    "Authorization": "Token c8e2a3d3c22d5750e6b5739800ebab5a334c9ee3",
    "Content-Type": "application/json"
}

# Data

data = '{"url":""}'


# Make the POST request
response = requests.post(url, headers=headers, data=data)

# Print the response (or process it as needed)
print(response.text)
# Out:
# {"err_code":"Unsupported Media Type","err_msg":"remote server failed to offer audio data. Content-Type of remote server's response was: text/plain","request_id":"169c63ed-c7ba-490b-b44a-6cddfc439fab"}

# %%
import requests
def getDeepgramTranscription(p_url):
    # Use this to get subtitles in English
    url = "https://api.deepgram.com/v1/listen?model=whisper-large&language=en&punctuate=true&diarize=true&smart_format=true"

    # Use this to get subtitles in the same language as the audio/video
    # url = "https://api.deepgram.com/v1/listen?model=whisper-large&detect_language=true"

    payload = {
        "url": p_url
    }

    headers = {
        "Authorization": "Token c8e2a3d3c22d5750e6b5739800ebab5a334c9ee3",
        "Content-Type": "application/json"
    }

    response = requests.request("POST", url, headers=headers, json=payload)

    output = response.json()
    words = output['results']['channels'][0]['alternatives'][0]['words']


    return words

my_file = "https://fpyltvtkpkrkzortucoa.supabase.co/storage/v1/object/public/media/726903182913934.mp3"
output = getDeepgramTranscription(my_file)
print(output)
# Out:
# [{'word': 'once', 'start': 0.06, 'end': 0.32, 'confidence': 0.9977393, 'speaker': 0, 'speaker_confidence': 1.0, 'punctuated_word': 'Once'}, {'word': 'upon', 'start': 0.32, 'end': 0.52, 'confidence': 0.80166465, 'speaker': 0, 'speaker_confidence': 1.0, 'punctuated_word': 'upon'}, {'word': 'a', 'start': 0.52, 'end': 0.71999997, 'confidence': 0.8915414, 'speaker': 0, 'speaker_confidence': 1.0, 'punctuated_word': 'a'}, {'word': 'time', 'start': 0.71999997, 'end': 1.16, 'confidence': 0.89327073, 'speaker': 0, 'speaker_confidence': 1.0, 'punctuated_word': 'time,'}, {'word': 'in', 'start': 1.16, 'end': 1.3, 'confidence': 0.84591675, 'speaker': 0, 'speaker_confidence': 1.0, 'punctuated_word': 'in'}, {'word': 'a', 'start': 1.3, 'end': 1.48, 'confidence': 0.5760524, 'speaker': 0, 'speaker_confidence': 1.0, 'punctuated_word': 'a'}, {'word': 'small', 'start': 1.48, 'end': 1.88, 'confidence': 0.85090685, 'speaker': 0, 'speaker_confidence': 1.0, 'punctuated_word': 'small'}, {'word': 'forgotten', '
# ...

# %%
print(words)
# Out:
# {'channels': [{'alternatives': [{'transcript': "Once upon a time in a small forgotten village, there lived a young person named Alex, whose days were spent toiling in the fields under the harsh sun. Alex's clothes were threadbare and their meals were often nothing more than scraps, but they harbored a dream brighter than the richest gold. 1 day, while wandering in the forest, Alex stumbled upon a hidden, ancient library brimming with forgotten knowledge and wisdom. Night after night, they pored over the books, learning about science, art, and the secrets of the universe. With this newfound knowledge, Alex invented a remarkable device that could clean water with incredible efficiency, revolutionizing the lives of many. News of Alex's invention spread like wildfire, bringing wealth, fame, and opportunities beyond their wildest dreams. From the shadows of obscurity, Alex had risen to become a beacon of hope and innovation, proving that even the humblest beginnings can lead to extraordin
# ...

# %%
import actions
import funcs_supabase

# %%
class SceneTimings:
    def __init__(self, project_id):
        # Constructor for the class. Initialize your attributes here
        self.project_id = project_id
        self.active_scenes = actions.get_active_scenes(self.project_id)
        self.scene_text_list = []
        for scene in self.active_scenes:
            scene_text = scene.get("scene_text")
            self.scene_text_list.append(scene_text)

            
        self.project_data = funcs_supabase.select_data("video_creator_projects", "id", self.project_id)[0]
        self.words_list = self.project_data.get("words_list")

# %%
st = SceneTimings(38)
# st.active_scenes
words_list = st.words_list
print(words_list)
print(len(words_list))
# Out:
# 2023-11-10 16:08:24,370:INFO - HTTP Request: GET https://fpyltvtkpkrkzortucoa.supabase.co/rest/v1/scenes?select=%2A&project_id=eq.38&status=eq.Active "HTTP/1.1 200 OK"
# 2023-11-10 16:08:24,487:INFO - HTTP Request: GET https://fpyltvtkpkrkzortucoa.supabase.co/rest/v1/video_creator_projects?select=%2A&id=eq.38 "HTTP/1.1 200 OK"
# ...

# %%
total_word_count = sum(len(s.split()) for s in st.scene_text_list)
total_word_count
# Out:
# 59

# %%
words_list =[{'end': 0.589, 'word': 'Margot', 'score': 0.792, 'start': 0.208}, {'end': 0.749, 'word': 'was', 'score': 0.761, 'start': 0.609}, {'end': 0.829, 'word': 'a', 'score': 0.999, 'start': 0.809}, {'end': 1.229, 'word': 'merle', 'score': 0.814, 'start': 0.909}, {'end': 1.75, 'word': 'golden', 'score': 0.892, 'start': 1.309}, {'end': 2.23, 'word': 'doodle', 'score': 0.8, 'start': 1.89}, {'end': 2.631, 'word': 'puppy.', 'score': 0.981, 'start': 2.29}, {'end': 3.251, 'word': 'She', 'score': 0.683, 'start': 3.151}, {'end': 3.392, 'word': 'was', 'score': 0.887, 'start': 3.291}, {'end': 3.752, 'word': 'afraid', 'score': 0.908, 'start': 3.452}, {'end': 3.852, 'word': 'of', 'score': 0.75, 'start': 3.792}, {'end': 4.333, 'word': 'everything,', 'score': 0.849, 'start': 3.932}, {'end': 4.813, 'word': 'plastic', 'score': 0.927, 'start': 4.373}, {'end': 5.214, 'word': 'bags,', 'score': 0.814, 'start': 4.833}, {'end': 5.554, 'word': 'loud', 'score': 0.855, 'start': 5.294}, {'end': 6.034, 'word': 'noises,', 'score': 0.822, 'start': 5.614}, {'end': 6.195, 'word': 'and', 'score': 0.82, 'start': 6.094}, {'end': 6.655, 'word': 'humans.', 'score': 0.955, 'start': 6.275}, {'end': 7.416, 'word': 'One', 'score': 0.834, 'start': 7.336}, {'end': 7.596, 'word': 'day,', 'score': 0.995, 'start': 7.456}, {'end': 9.518, 'word': 'Jimmy', 'score': 0.884, 'start': 9.218}, {'end': 9.778, 'word': 'came', 'score': 0.688, 'start': 9.578}, {'end': 9.899, 'word': 'to', 'score': 0.754, 'start': 9.838}, {'end': 10.239, 'word': 'stay.', 'score': 0.918, 'start': 9.959}, {'end': 10.379, 'word': 'At', 'score': 0.736, 'start': 10.299}, {'end': 10.639, 'word': 'first,', 'score': 0.791, 'start': 10.419}, {'end': 10.779, 'word': 'she', 'score': 0.794, 'start': 10.679}, {'end': 10.94, 'word': 'was', 'score': 0.68, 'start': 10.819}, {'end': 11.48, 'word': 'unsure,', 'score': 0.806, 'start': 11.02}, {'end': 11.961, 'word': 'and', 'score': 0.835, 'start': 11.861}, {'end': 12.141, 'word': 'she', 'score': 0.648, 'start': 12.001}, {'end': 12.361, 'word': 'hid', 'score': 0.877, 'start': 12.181}, {'end': 12.581, 'word': 'under', 'score': 0.841, 'start': 12.401}, {'end': 12.701, 'word': 'the', 'score': 0.832, 'start': 12.621}, {'end': 12.982, 'word': 'bed.', 'score': 0.82, 'start': 12.742}, {'end': 13.843, 'word': 'After', 'score': 0.884, 'start': 13.622}, {'end': 13.903, 'word': 'a', 'score': 1.0, 'start': 13.883}, {'end': 14.143, 'word': 'few', 'score': 0.875, 'start': 13.963}, {'end': 14.443, 'word': 'days', 'score': 0.688, 'start': 14.203}, {'end': 14.563, 'word': 'of', 'score': 0.75, 'start': 14.503}, {'end': 14.844, 'word': 'being', 'score': 0.851, 'start': 14.624}, {'end': 15.124, 'word': 'fed', 'score': 0.886, 'start': 14.904}, {'end': 15.424, 'word': 'lots', 'score': 0.915, 'start': 15.184}, {'end': 15.545, 'word': 'of', 'score': 0.816, 'start': 15.484}, {'end': 15.945, 'word': 'treats,', 'score': 0.84, 'start': 15.645}, {'end': 16.145, 'word': 'she', 'score': 0.72, 'start': 16.005}, {'end': 16.506, 'word': 'started', 'score': 0.966, 'start': 16.185}, {'end': 16.646, 'word': 'to', 'score': 0.912, 'start': 16.546}, {'end': 16.966, 'word': 'like', 'score': 0.989, 'start': 16.746}, {'end': 17.326, 'word': 'Jimmy.', 'score': 0.9, 'start': 17.046}, {'end': 17.627, 'word': 'After', 'score': 0.916, 'start': 17.427}, {'end': 17.767, 'word': 'the', 'score': 0.81, 'start': 17.667}, {'end': 18.107, 'word': 'third', 'score': 0.705, 'start': 17.827}, {'end': 18.368, 'word': 'day,', 'score': 0.877, 'start': 18.167}, {'end': 18.548, 'word': 'they', 'score': 0.836, 'start': 18.428}, {'end': 18.688, 'word': 'were', 'score': 0.876, 'start': 18.568}, {'end': 18.948, 'word': 'best', 'score': 0.768, 'start': 18.728}, {'end': 19.409, 'word': 'friends.', 'score': 0.791, 'start': 19.028}]
for word in words_list:
    print(word)
# Out:
# {'end': 0.589, 'word': 'Margot', 'score': 0.792, 'start': 0.208}
# {'end': 0.749, 'word': 'was', 'score': 0.761, 'start': 0.609}
# {'end': 0.829, 'word': 'a', 'score': 0.999, 'start': 0.809}
# {'end': 1.229, 'word': 'merle', 'score': 0.814, 'start': 0.909}
# {'end': 1.75, 'word': 'golden', 'score': 0.892, 'start': 1.309}
# {'end': 2.23, 'word': 'doodle', 'score': 0.8, 'start': 1.89}
# {'end': 2.631, 'word': 'puppy.', 'score': 0.981, 'start': 2.29}
# {'end': 3.251, 'word': 'She', 'score': 0.683, 'start': 3.151}
# {'end': 3.392, 'word': 'was', 'score': 0.887, 'start': 3.291}
# {'end': 3.752, 'word': 'afraid', 'score': 0.908, 'start': 3.452}
# {'end': 3.852, 'word': 'of', 'score': 0.75, 'start': 3.792}
# {'end': 4.333, 'word': 'everything,', 'score': 0.849, 'start': 3.932}
# {'end': 4.813, 'word': 'plastic', 'score': 0.927, 'start': 4.373}
# {'end': 5.214, 'word': 'bags,', 'score': 0.814, 'start': 4.833}
# {'end': 5.554, 'word': 'loud', 'score': 0.855, 'start': 5.294}
# ...

# %%
def get_words(string):
    words_list = string.split()
    return words_list

# %%
scene_timings_list = []


scene_text_list = st.scene_text_list
for item in scene_text_list:
    print(item)
    scene_timings_dict = {"end": None, "start": None, "length": None}
    scene_timings_list.append(scene_timings_dict)
# Out:
# Margot was a merle golden doodle puppy.
# She was afraid of everything - plastic bags, loud noises, and humans.
# One day Jimmy came to stay.
# At first she was unsure and she hid under the bed.
# After a few days of being fed lots of treats, she started to like Jimmy.
# After the 3rd day, they were best friends!

# %%
def words_list_occorunces(string):
    words_list = st.words_list
    matched_positions = []

    for p, word in enumerate(words_list):

        word = word.get("word")
        filtered_lowercase_word = ''.join(filter(str.isalnum, word)).lower()
        filtered_lowercase_string = ''.join(filter(str.isalnum, string)).lower()

        if filtered_lowercase_word == filtered_lowercase_string:
            matched_positions.append(p)

    if (len(matched_positions)>0):
        found = True
    else:
        found = False


    return found, matched_positions



words_list_occorunces("dog")
# Out:
# (False, [])

# %%
scene_text_list = st.scene_text_list

for scene_no, scene_text in enumerate(scene_text_list):
    scene_text = scene_text.lower()
    allowed_characters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789 "
    scene_text = "".join(char for char in scene_text if char in allowed_characters)
    words = scene_text.split()
    print(words)
    
    fail_count = 0
    words_length = len(words)
    print(words_length)


    for range_no in range(words_length):
        # print(range_no) 
        word = words[range_no]
        # print(word)
        found, matched_positions = words_list_occorunces(word)
        # print(found)
        if found == False:
            fail_count += 1

    print("scene finished with fail_count", fail_count)
    print(words[0])
    print(words[-1])






    # for word_no, word in enumerate(words):
    #     found, matched_positions = words_list_occorunces(word)
    #     # print(found)
    #     if found == False:
    #         fail_count += 1


    # print("scene finished with fail_count", fail_count)
    # # print(first_word = words[0])
# Out:
# ['margot', 'was', 'a', 'merle', 'golden', 'doodle', 'puppy']
# 7
# scene finished with fail_count 0
# margot
# puppy
# ['she', 'was', 'afraid', 'of', 'everything', 'plastic', 'bags', 'loud', 'noises', 'and', 'humans']
# 11
# scene finished with fail_count 0
# she
# humans
# ['one', 'day', 'jimmy', 'came', 'to', 'stay']
# 6
# scene finished with fail_count 0
# one
# stay
# ['at', 'first', 'she', 'was', 'unsure', 'and', 'she', 'hid', 'under', 'the', 'bed']
# 11
# scene finished with fail_count 0
# at
# bed
# ['after', 'a', 'few', 'days', 'of', 'being', 'fed', 'lots', 'of', 'treats', 'she', 'started', 'to', 'like', 'jimmy']
# 15
# scene finished with fail_count 0
# after
# jimmy
# ['after', 'the', '3rd', 'day', 'they', 'were', 'best', 'friends']
# 8
# scene finished with fail_count 1
# after
# friends

# %%
scene_timings = []

words_list = st.words_list
word_number = 0



def clean_string(scene_text):
    scene_text = scene_text.lower()
    allowed_characters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789 "
    scene_text = "".join(char for char in scene_text if char in allowed_characters)
    return scene_text


# loop through every word in the scene text
scene_text_list = st.scene_text_list
for scene_no, scene_text in enumerate(scene_text_list):
    print (f"scene no: {scene_no}")
    
    # clean up scene text
    scene_text = clean_string(scene_text)
    scene_words = scene_text.split()
    print(scene_words)

    # loop through every word in the scene text
    scene_word_count = len(scene_words)
    scene_fails = 0
    for scene_word in scene_words:
        # print(words_list[word_number])
        word_from_word_list = words_list[word_number].get("word")
        word_from_word_list = clean_string(word_from_word_list)


        if scene_word != word_from_word_list:
            print(f"no match {scene_word} {word_from_word_list}")
            scene_fails += 1


        word_number += 1


    print(f"scene complete fails: {scene_fails} / {scene_word_count}")

    if scene_fails < 3:

        first_word  = words_list[word_number - scene_word_count]
        last_word = words_list[word_number - 1]

        dict_to_add = {"end": last_word["end"], "start": first_word["start"], "length": round(last_word["end"] - first_word["start"], 3)}
        scene_timings.append(dict_to_add)

    else:
        print("scene failed")
        dict_to_add = {"end": None, "start": None, "length": None}
        scene_timings.append(dict_to_add)



print(scene_timings)
# Out:
# scene no: 0
# ['margot', 'was', 'a', 'merle', 'golden', 'doodle', 'puppy']
# scene complete fails: 0 / 7
# scene no: 1
# ['she', 'was', 'afraid', 'of', 'everything', 'plastic', 'bags', 'loud', 'noises', 'and', 'humans']
# scene complete fails: 0 / 11
# scene no: 2
# ['one', 'day', 'jimmy', 'came', 'to', 'stay']
# scene complete fails: 0 / 6
# scene no: 3
# ['at', 'first', 'she', 'was', 'unsure', 'and', 'she', 'hid', 'under', 'the', 'bed']
# scene complete fails: 0 / 11
# scene no: 4
# ['after', 'a', 'few', 'days', 'of', 'being', 'fed', 'lots', 'of', 'treats', 'she', 'started', 'to', 'like', 'jimmy']
# scene complete fails: 0 / 15
# scene no: 5
# ['after', 'the', '3rd', 'day', 'they', 'were', 'best', 'friends']
# no match 3rd third
# scene complete fails: 1 / 8
# ...

# %%
def clean_string(text):
    """
    Cleans a given string by converting it to lowercase and removing any characters
    that are not letters, numbers, or spaces.

    :param text: The string to be cleaned.
    :return: The cleaned string.
    """
    text = text.lower()
    allowed_characters = "abcdefghijklmnopqrstuvwxyz0123456789 "
    return "".join(char for char in text if char in allowed_characters)

def process_scene(scene_text, words_list, word_number):
    """
    Processes a single scene, comparing words in the scene with words from a list.

    :param scene_text: Text of the scene.
    :param words_list: List of words with timing information.
    :param word_number: Current word number index.
    :return: Tuple containing updated word_number, scene_fails count, and scene_word_count.
    """
    scene_text = clean_string(scene_text)
    scene_words = scene_text.split()
    print(f"Scene words: {scene_words}")

    scene_fails = 0
    for scene_word in scene_words:
        word_from_word_list = words_list[word_number].get("word")
        word_from_word_list = clean_string(word_from_word_list)

        if scene_word != word_from_word_list:
            print(f"No match {scene_word} {word_from_word_list}")
            scene_fails += 1

        word_number += 1

    scene_word_count = len(scene_words)
    return word_number, scene_fails, scene_word_count

def main():
    scene_timings = []
    words_list = st.words_list  # Assuming 'st' is a previously defined object
    word_number = 0

    # Process each scene in the scene text list
    for scene_no, scene_text in enumerate(st.scene_text_list):
        print(f"Processing scene number: {scene_no}")

        word_number, scene_fails, scene_word_count = process_scene(scene_text, words_list, word_number)
        print(f"Scene complete - fails: {scene_fails} / {scene_word_count}")

        # Add timing information based on fails count
        if scene_fails < 3:
            first_word = words_list[word_number - scene_word_count]
            last_word = words_list[word_number - 1]

            timing_info = {
                "end": last_word["end"],
                "start": first_word["start"],
                "length": round(last_word["end"] - first_word["start"], 3)
            }
        else:
            print("Scene failed")
            timing_info = {"end": None, "start": None, "length": None}

        scene_timings.append(timing_info)

    print(scene_timings)

if __name__ == "__main__":
    main()
# Out:
# Processing scene number: 0
# Scene words: ['margot', 'was', 'a', 'merle', 'golden', 'doodle', 'puppy']
# Scene complete - fails: 0 / 7
# Processing scene number: 1
# Scene words: ['she', 'was', 'afraid', 'of', 'everything', 'plastic', 'bags', 'loud', 'noises', 'and', 'humans']
# Scene complete - fails: 0 / 11
# Processing scene number: 2
# Scene words: ['one', 'day', 'jimmy', 'came', 'to', 'stay']
# Scene complete - fails: 0 / 6
# Processing scene number: 3
# Scene words: ['at', 'first', 'she', 'was', 'unsure', 'and', 'she', 'hid', 'under', 'the', 'bed']
# Scene complete - fails: 0 / 11
# Processing scene number: 4
# Scene words: ['after', 'a', 'few', 'days', 'of', 'being', 'fed', 'lots', 'of', 'treats', 'she', 'started', 'to', 'like', 'jimmy']
# Scene complete - fails: 0 / 15
# Processing scene number: 5
# Scene words: ['after', 'the', '3rd', 'day', 'they', 'were', 'best', 'friends']
# No match 3rd third
# Scene complete - fails: 1 / 8
# ...

# %%
import os
from pydub import AudioSegment
import requests

class SceneTimings:
    def __init__(self, project_id):
        self.project_id = project_id
        self.active_scenes = actions.get_active_scenes(self.project_id)
        self.scene_text_list = [scene.get("scene_text") for scene in self.active_scenes]
        self.project_data = funcs_supabase.select_data("video_creator_projects", "id", self.project_id)[0]
        self.words_list = self.project_data.get("words_list")

    @staticmethod
    def clean_string(text):
        text = text.lower()
        allowed_characters = "abcdefghijklmnopqrstuvwxyz0123456789 "
        return "".join(char for char in text if char in allowed_characters)

    def process_scene(self, scene_text, word_number):
        scene_text = self.clean_string(scene_text)
        scene_words = scene_text.split()
        print(f"Scene words: {scene_words}")

        scene_fails = 0
        for scene_word in scene_words:
            word_from_word_list = self.words_list[word_number].get("word")
            word_from_word_list = self.clean_string(word_from_word_list)

            if scene_word != word_from_word_list:
                print(f"No match {scene_word} {word_from_word_list}")
                scene_fails += 1

            word_number += 1

        scene_word_count = len(scene_words)
        return word_number, scene_fails, scene_word_count

    def calculate_timings(self):
        scene_timings = []
        word_number = 0

        for scene_no, scene_text in enumerate(self.scene_text_list):
            print(f"Processing scene number: {scene_no}")

            word_number, scene_fails, scene_word_count = self.process_scene(scene_text, word_number)
            print(f"Scene complete - fails: {scene_fails} / {scene_word_count}")

            if scene_fails < 3:
                first_word = self.words_list[word_number - scene_word_count]
                last_word = self.words_list[word_number - 1]

                timing_info = {
                    "end": last_word["end"],
                    "start": first_word["start"],
                    "length": round(last_word["end"] - first_word["start"], 3)
                }
            else:
                print("Scene failed")
                timing_info = {"end": None, "start": None, "length": None}

            scene_timings.append(timing_info)

        print(scene_timings)
        return scene_timings



    def process_scene_timings(self, scene_timings_raw):
        audio_duration = self.get_audio_duration()

        scene_timings_processed = []
        for i, scene in enumerate(scene_timings_raw):
            if i == 0:
                scene["start"] = 0
            else:
                scene["start"] = scene_timings_raw[i-1]["end"]
            
            if i < len(scene_timings_raw) - 1:
                scene["end"] = scene_timings_raw[i+1]["start"]
            else:
                scene["end"] = audio_duration

            scene["start"] = round(scene["start"], 3)
            scene["end"] = round(scene["end"], 3)
            scene["length"] = round(scene["end"] - scene["start"], 3)

            scene_timings_processed.append(scene)

        return scene_timings_processed

    def update_timings_database(self, processed_scene_timings):
        if len(self.active_scenes) != len(processed_scene_timings):
            print("Scene count mismatch between database and processed timings.")
            return

        responses = []
        for i, scene in enumerate(processed_scene_timings):
            data_to_update = {
                "length": scene["length"],
                "start": scene["start"],
                "end": scene["end"]
            }

            scene_id = self.active_scenes[i]["id"]
            print(f"Updating scene {scene_id} with {data_to_update}")
            update_response = funcs_supabase.update_data("scenes", scene_id, {"timings": data_to_update})
            print(update_response)
            print("\n")
            responses.append(update_response)

        return responses

    def get_audio_duration(self):
        # Assume funcs_supabase.select_data() returns the necessary data
        audio_file_url = funcs_supabase.select_data("video_creator_projects", "id", project_id)[0].get("speech_audio")

        # Specify the folder where the audio file will be downloaded
        download_folder = "downloaded_audio"
        os.makedirs(download_folder, exist_ok=True)

        # Extract the filename and create a path for the downloaded file
        filename = os.path.basename(audio_file_url)
        file_path = os.path.join(download_folder, filename)

        # Download the audio file
        response = requests.get(audio_file_url)
        if response.status_code == 200:
            with open(file_path, 'wb') as file:
                file.write(response.content)
        else:
            raise Exception("Failed to download the audio file")

        try:
            # Load the audio file and get its duration
            audio = AudioSegment.from_file(file_path)
            duration_seconds = len(audio) / 1000  # pydub calculates in millisec
        finally:
            # Delete the audio file after processing
            if os.path.exists(file_path):
                os.remove(file_path)

        return duration_seconds


# Example usage
project_id = 38
scene_timing_instance = SceneTimings(project_id)

# Process and update scene timings
raw_timings = scene_timing_instance.calculate_timings()  # Assuming calculate_timings is implemented as in previous examples
processed_timings = scene_timing_instance.process_scene_timings(raw_timings)
update_responses = scene_timing_instance.update_timings_database(processed_timings)
# Out:
# 2023-11-10 18:32:11,434:INFO - HTTP Request: GET https://fpyltvtkpkrkzortucoa.supabase.co/rest/v1/scenes?select=%2A&project_id=eq.38&status=eq.Active "HTTP/1.1 200 OK"
# 2023-11-10 18:32:11,542:INFO - HTTP Request: GET https://fpyltvtkpkrkzortucoa.supabase.co/rest/v1/video_creator_projects?select=%2A&id=eq.38 "HTTP/1.1 200 OK"
# 2023-11-10 18:32:11,668:INFO - HTTP Request: GET https://fpyltvtkpkrkzortucoa.supabase.co/rest/v1/video_creator_projects?select=%2A&id=eq.%3C__main__.SceneTimings%20object%20at%200x2b1bc8fd0%3E "HTTP/1.1 400 Bad Request"
# Processing scene number: 0
# Scene words: ['margot', 'was', 'a', 'merle', 'golden', 'doodle', 'puppy']
# Scene complete - fails: 0 / 7
# Processing scene number: 1
# Scene words: ['she', 'was', 'afraid', 'of', 'everything', 'plastic', 'bags', 'loud', 'noises', 'and', 'humans']
# Scene complete - fails: 0 / 11
# Processing scene number: 2
# Scene words: ['one', 'day', 'jimmy', 'came', 'to', 'stay']
# Scene complete - fails: 0 / 6
# ...
