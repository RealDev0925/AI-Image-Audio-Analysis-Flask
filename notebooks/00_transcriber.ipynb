# %%
import re
from datetime import timedelta

def convert_seconds_to_time(seconds):
    # Convert seconds to a string in the format 'HH:MM:SS'
    return str(timedelta(seconds=seconds))

def generate_srt_content(word_segments, max_chars=1):
    # Initialize some stuff
    srt_content = ""
    current_block = ""
    srt_segment_n = 1  # This is the subtitle number in the SRT file
    previous_end = 0  # Keep track of where the last word ended

    # Loop through each word to make sure it has a start and end time
    for i, word in enumerate(word_segments):
        if 'start' not in word or 'end' not in word:
            word['start'] = previous_end
            word['end'] = previous_end + 4  # If we don't know when it ends, just add 4 seconds

        # Update the end time for the next loop
        previous_end = word['end']

    # If the first word doesn't start at 0, add an empty subtitle at the beginning
    if word_segments[0]['start'] != 0:
        srt_content += f"1\n00:00:00,000 --> {convert_seconds_to_time(word_segments[0]['start'])}\n\n"
        srt_segment_n = 2  # Start the next subtitle at 2

    # Initialize the start and end times for the first block
    block_start_time = convert_seconds_to_time(word_segments[0]['start'])
    block_end_time = block_start_time

    # Loop through each word to build the SRT content
    for word in word_segments:
        next_word = word["word"] + " "

        # Check if we should start a new subtitle block
        if re.search(r'[.!?]\s*$', current_block) or len(current_block + next_word) > max_chars:
            srt_content += f"{srt_segment_n}\n{block_start_time} --> {block_end_time}\n{current_block.strip()}\n\n"
            srt_segment_n += 1
            block_start_time = block_end_time
            current_block = next_word
        else:
            current_block += next_word
            block_end_time = convert_seconds_to_time(word['end'])

    # Don't forget the last block!
    if current_block.strip():
        srt_content += f"{srt_segment_n}\n{block_start_time} --> {block_end_time}\n{current_block.strip()}\n\n"

    return srt_content

def save_srt_to_file(save_to, srt_content):
    # Create the full path for the new SRT file
    file_path = f"saved_srt_files/{save_to}_subtitles.srt"

    # If the file already exists, delete it
    if os.path.exists(file_path):
        os.remove(file_path)

    # Write the new SRT content to the file
    with open(file_path, 'a', encoding='utf-8') as srtFile:
        srtFile.write(srt_content)

    return os.path.basename(file_path)

# Example usage
word_segments = [
    {"word": "Hello", "start": 0.5, "end": 1},
    {"word": "world", "start": 4, "end": 5},
    {"word": ".", "start": 5, "end": 20}
]

srt_content = generate_srt_content(word_segments)
print(srt_content)  # This will print the SRT content
# save_srt_to_file("example", srt_content)  # Uncomment this to save the SRT content to a file
# Out:
# 1
# 00:00:00,000 --> 0:00:00.500000
#
# 2
# 0:00:00.500000 --> 0:00:00.500000
#
#
# 3
# 0:00:00.500000 --> 0:00:00.500000
# Hello
#
# 4
# 0:00:00.500000 --> 0:00:00.500000
# world
#
# 5
# 0:00:00.500000 --> 0:00:00.500000
# .

# %%
import replicate
def get_word_segments (audio_file_binary):
    output = replicate.run("daanelson/whisperx:9aa6ecadd30610b81119fc1b6807302fd18ca6cbb39b3216f430dcf23618cedd",input={"audio": audio_file_binary, "align_output": True})
 
    list_of_word_dicts = []
    for item_1 in output:
        # print(item_1)
        item_words = item_1['words']
        # print(item_words)
        for innter_words in item_words:
            # print(innter_words)
            list_of_word_dicts.append(innter_words)
    return list_of_word_dicts



audio_filepath = "transcriber/input_audio/test1.mp3"
audio_file_binary = open(audio_filepath, "rb")
word_segments = get_word_segments(audio_file_binary)
for word_segment in word_segments:
    print(word_segment)
# Out:
# {'end': 0.348, 'score': 0.789, 'start': 0.248, 'word': 'Are'}
# {'end': 0.529, 'score': 0.8, 'start': 0.388, 'word': 'you'}
# {'end': 0.909, 'score': 0.891, 'start': 0.629, 'word': 'ready'}
# {'end': 1.049, 'score': 0.918, 'start': 0.989, 'word': 'to'}
# {'end': 1.35, 'score': 0.836, 'start': 1.089, 'word': 'become'}
# {'end': 1.43, 'score': 0.748, 'start': 1.37, 'word': 'an'}
# {'end': 2.111, 'score': 0.887, 'start': 1.65, 'word': 'online'}
# {'end': 2.671, 'score': 0.825, 'start': 2.151, 'word': 'millionaire?'}
# {'end': 3.072, 'score': 0.838, 'start': 2.731, 'word': 'Discover'}
# {'end': 3.172, 'score': 0.836, 'start': 3.092, 'word': 'the'}
# {'end': 3.472, 'score': 0.824, 'start': 3.212, 'word': 'secret'}
# {'end': 3.572, 'score': 0.749, 'start': 3.512, 'word': 'to'}
# {'end': 3.893, 'score': 0.905, 'start': 3.613, 'word': 'making'}
# {'end': 4.534, 'score': 0.847, 'start': 4.033, 'word': 'thousands'}
# {'end': 4.674, 'score': 0.972, 'start': 4.574, 'word': 'from'}
# {'end': 4.794, 'score': 0.833, 'start': 4.714, 'word': 'the'}
# {'end': 5.154, 'score': 0.875, 'start': 4.834, 'word': 'comfort'}
# {'end': 5.215, 'score': 1, 'start': 5.174, 'word': 'of'}
# {'end': 5.395, 'score': 0.896, 'start': 5.255, 'word': 'your'}
# {'end': 5.575, 'score': 0.777, 'start': 5.455, 'word': 'own'}
# {'end': 5.875, 'score': 0.855, 'start': 5.635, 'word': 'home'}
# {'end': 6.076, 'score': 0.752, 'start': 5.935, 'word': 'with'}
# {'end': 6.296, 'score': 0.983, 'start': 6.156, 'word': 'no'}
# {'end': 6.877, 'score': 0.898, 'start': 6.356, 'word': 'experience'}
# {'end': 7.217, 'score': 0.808, 'start': 6.937, 'word': 'needed.'}
# {'end': 8.479, 'score': 0.864, 'start': 8.318, 'word': 'This'}
# {'end': 8.999, 'score': 0.801, 'start': 8.519, 'word': 'guaranteed'}
# {'end': 9.36, 'score': 0.901, 'start': 9.059, 'word': 'method'}
# {'end': 9.74, 'score': 0.92, 'start': 9.4, 'word': 'allows'}
# {'end': 9.88, 'score': 0.722, 'start': 9.76, 'word': 'you'}
# {'end': 9.96, 'score': 0.75, 'start': 9.9, 'word': 'to'}
# {'end': 10.441, 'score': 0.85, 'start': 10.161, 'word': 'always'}
# {'end': 10.701, 'score': 0.82, 'start': 10.501, 'word': 'win'}
# {'end': 10.801, 'score': 0.742, 'start': 10.741, 'word': 'at'}
# {'end': 11.222, 'score': 0.988, 'start': 10.942, 'word': 'online'}
# {'end': 11.763, 'score': 0.966, 'start': 11.262, 'word': 'casinos.'}
# {'end': 12.882, 'score': 0.899, 'start': 12.642, 'word': 'Now'}
# {'end': 13.062, 'score': 0.833, 'start': 12.962, 'word': 'you'}
# {'end': 13.203, 'score': 0.999, 'start': 13.102, 'word': 'can'}
# {'end': 13.363, 'score': 0.832, 'start': 13.243, 'word': 'get'}
# {'end': 13.483, 'score': 0.834, 'start': 13.403, 'word': 'the'}
# {'end': 13.723, 'score': 0.978, 'start': 13.583, 'word': 'edge'}
# {'end': 13.863, 'score': 0.727, 'start': 13.763, 'word': 'and'}
# {'end': 14.263, 'score': 0.801, 'start': 13.903, 'word': 'ensure'}
# {'end': 14.443, 'score': 0.778, 'start': 14.303, 'word': 'your'}
# {'end': 14.864, 'score': 0.74, 'start': 14.463, 'word': 'success'}
# {'end': 15.264, 'score': 0.794, 'start': 15.024, 'word': 'every'}
# {'end': 15.524, 'score': 0.765, 'start': 15.304, 'word': 'time.'}
# {'end': 15.724, 'score': 0.845, 'start': 15.584, 'word': 'This'}
# {'end': 16.225, 'score': 0.921, 'start': 15.784, 'word': 'amazing'}
# {'end': 16.745, 'score': 0.786, 'start': 16.285, 'word': 'loophole'}
# {'end': 17.105, 'score': 0.952, 'start': 16.785, 'word': 'allows'}
# {'end': 17.246, 'score': 0.831, 'start': 17.145, 'word': 'you'}
# {'end': 17.346, 'score': 0.75, 'start': 17.286, 'word': 'to'}
# {'end': 17.566, 'score': 0.721, 'start': 17.386, 'word': 'take'}
# {'end': 18.046, 'score': 0.828, 'start': 17.606, 'word': 'advantage'}
# {'end': 18.146, 'score': 0.75, 'start': 18.086, 'word': 'of'}
# {'end': 18.246, 'score': 0.999, 'start': 18.186, 'word': 'the'}
# {'end': 18.486, 'score': 0.73, 'start': 18.306, 'word': 'free'}
# {'end': 19.027, 'score': 0.833, 'start': 18.527, 'word': 'bonuses'}
# {'end': 19.267, 'score': 0.825, 'start': 19.067, 'word': 'given'}
# {'end': 19.427, 'score': 0.866, 'start': 19.327, 'word': 'out'}
# {'end': 19.587, 'score': 0.817, 'start': 19.467, 'word': 'by'}
# {'end': 20.048, 'score': 0.884, 'start': 19.707, 'word': 'online'}
# {'end': 20.608, 'score': 0.858, 'start': 20.088, 'word': 'casinos.'}
# {'end': 21.148, 'score': 0.758, 'start': 21.008, 'word': 'With'}
# {'end': 21.349, 'score': 0.92, 'start': 21.209, 'word': 'each'}
# {'end': 21.789, 'score': 0.839, 'start': 21.429, 'word': 'spin,'}
# {'end': 22.149, 'score': 0.833, 'start': 22.049, 'word': 'you'}
# {'end': 22.289, 'score': 0.887, 'start': 22.169, 'word': 'can'}
# {'end': 22.489, 'score': 0.873, 'start': 22.329, 'word': 'win'}
# {'end': 23.03, 'score': 0.768, 'start': 22.65, 'word': 'anywhere'}
# {'end': 23.37, 'score': 0.771, 'start': 23.07, 'word': 'between'}
# {'word': '$50'}
# {'end': 24.331, 'score': 0.797, 'start': 24.031, 'word': 'and'}
# {'word': '$3'}
# {'end': 25.051, 'score': 0.731, 'start': 24.711, 'word': 'million.'}
# {'end': 26.072, 'score': 0.797, 'start': 25.352, 'word': 'And'}
# {'end': 26.252, 'score': 0.731, 'start': 26.112, 'word': "it's"}
# {'end': 26.953, 'score': 0.837, 'start': 26.292, 'word': 'completely'}
# {'end': 27.453, 'score': 0.771, 'start': 27.073, 'word': 'legal'}
# {'end': 27.873, 'score': 0.829, 'start': 27.773, 'word': 'and'}
# {'end': 28.394, 'score': 0.894, 'start': 27.934, 'word': 'risk-free'}
# {'end': 28.534, 'score': 0.771, 'start': 28.414, 'word': 'for'}
# {'end': 28.994, 'score': 0.921, 'start': 28.554, 'word': 'Canadians.'}
# {'end': 29.174, 'score': 0.878, 'start': 29.054, 'word': 'This'}
# {'end': 29.495, 'score': 0.903, 'start': 29.214, 'word': 'loophole'}
# {'end': 29.655, 'score': 0.915, 'start': 29.535, 'word': 'will'}
# {'end': 29.795, 'score': 0.858, 'start': 29.695, 'word': 'not'}
# {'end': 30.035, 'score': 0.844, 'start': 29.835, 'word': 'last'}
# {'end': 30.255, 'score': 0.887, 'start': 30.075, 'word': 'long.'}
# {'end': 30.475, 'score': 0.845, 'start': 30.295, 'word': 'Click'}
# {'end': 30.576, 'score': 0.833, 'start': 30.495, 'word': 'the'}
# {'end': 30.816, 'score': 0.844, 'start': 30.596, 'word': 'button'}
# {'end': 31.056, 'score': 0.875, 'start': 30.836, 'word': 'below'}
# {'end': 31.196, 'score': 0.843, 'start': 31.116, 'word': 'and'}
# {'end': 31.456, 'score': 0.788, 'start': 31.216, 'word': 'collect'}
# {'end': 31.576, 'score': 0.979, 'start': 31.476, 'word': 'your'}
# {'end': 31.756, 'score': 0.869, 'start': 31.596, 'word': 'free'}
# {'end': 32.017, 'score': 0.847, 'start': 31.776, 'word': 'spins'}
# {'end': 32.237, 'score': 0.955, 'start': 32.057, 'word': 'now.'}

# %%
srt_contents = generate_srt_content(word_segments)
print(srt_contents)
# Out:
# 1
# 00:00:00,000 --> 0:00:00.248000
#
# 2
# 0:00:00.248000 --> 0:00:00.248000
#
#
# 3
# 0:00:00.248000 --> 0:00:00.248000
# Are
#
# 4
# 0:00:00.248000 --> 0:00:00.248000
# you
#
# 5
# 0:00:00.248000 --> 0:00:00.248000
# ready
#
# 6
# 0:00:00.248000 --> 0:00:00.248000
# to
#
# 7
# 0:00:00.248000 --> 0:00:00.248000
# become
#
# 8
# 0:00:00.248000 --> 0:00:00.248000
# an
#
# 9
# 0:00:00.248000 --> 0:00:00.248000
# online
#
# 10
# 0:00:00.248000 --> 0:00:00.248000
# millionaire?
#
# 11
# 0:00:00.248000 --> 0:00:00.248000
# Discover
#
# 12
# 0:00:00.248000 --> 0:00:00.248000
# the
#
# 13
# 0:00:00.248000 --> 0:00:00.248000
# secret
#
# 14
# 0:00:00.248000 --> 0:00:00.248000
# to
#
# 15
# 0:00:00.248000 --> 0:00:00.248000
# making
#
# 16
# 0:00:00.248000 --> 0:00:00.248000
# thousands
#
# 17
# 0:00:00.248000 --> 0:00:00.248000
# from
#
# 18
# 0:00:00.248000 --> 0:00:00.248000
# the
#
# 19
# 0:00:00.248000 --> 0:00:00.248000
# comfort
#
# 20
# 0:00:00.248000 --> 0:00:00.248000
# of
#
# 21
# 0:00:00.248000 --> 0:00:00.248000
# your
#
# 22
# 0:00:00.248000 --> 0:00:00.248000
# own
#
# 23
# 0:00:00.248000 --> 0:00:00.248000
# home
#
# 24
# 0:00:00.248000 --> 0:00:00.248000
# with
#
# 25
# 0:00:00.248000 --> 0:00:00.248000
# no
#
# 26
# 0:00:00.248000 --> 0:00:00.248000
# experience
#
# 27
# 0:00:00.248000 --> 0:00:00.248000
# needed.
#
# 28
# 0:00:00.248000 --> 0:00:00.248000
# This
#
# 29
# 0:00:00.248000 --> 0:00:00.248000
# guaranteed
#
# 30
# 0:00:00.248000 --> 0:00:00.248000
# method
#
# 31
# 0:00:00.248000 --> 0:00:00.248000
# allows
#
# 32
# 0:00:00.248000 --> 0:00:00.248000
# you
#
# 33
# 0:00:00.248000 --> 0:00:00.248000
# to
#
# 34
# 0:00:00.248000 --> 0:00:00.248000
# always
#
# 35
# 0:00:00.248000 --> 0:00:00.248000
# win
#
# 36
# 0:00:00.248000 --> 0:00:00.248000
# at
#
# 37
# 0:00:00.248000 --> 0:00:00.248000
# online
#
# 38
# 0:00:00.248000 --> 0:00:00.248000
# casinos.
#
# 39
# 0:00:00.248000 --> 0:00:00.248000
# Now
#
# 40
# 0:00:00.248000 --> 0:00:00.248000
# you
#
# 41
# 0:00:00.248000 --> 0:00:00.248000
# can
#
# 42
# 0:00:00.248000 --> 0:00:00.248000
# get
#
# 43
# 0:00:00.248000 --> 0:00:00.248000
# the
#
# 44
# 0:00:00.248000 --> 0:00:00.248000
# edge
#
# 45
# 0:00:00.248000 --> 0:00:00.248000
# and
#
# 46
# 0:00:00.248000 --> 0:00:00.248000
# ensure
#
# 47
# 0:00:00.248000 --> 0:00:00.248000
# your
#
# 48
# 0:00:00.248000 --> 0:00:00.248000
# success
#
# 49
# 0:00:00.248000 --> 0:00:00.248000
# every
#
# 50
# 0:00:00.248000 --> 0:00:00.248000
# time.
#
# 51
# 0:00:00.248000 --> 0:00:00.248000
# This
#
# 52
# 0:00:00.248000 --> 0:00:00.248000
# amazing
#
# 53
# 0:00:00.248000 --> 0:00:00.248000
# loophole
#
# 54
# 0:00:00.248000 --> 0:00:00.248000
# allows
#
# 55
# 0:00:00.248000 --> 0:00:00.248000
# you
#
# 56
# 0:00:00.248000 --> 0:00:00.248000
# to
#
# 57
# 0:00:00.248000 --> 0:00:00.248000
# take
#
# 58
# 0:00:00.248000 --> 0:00:00.248000
# advantage
#
# 59
# 0:00:00.248000 --> 0:00:00.248000
# of
#
# 60
# 0:00:00.248000 --> 0:00:00.248000
# the
#
# 61
# 0:00:00.248000 --> 0:00:00.248000
# free
#
# 62
# 0:00:00.248000 --> 0:00:00.248000
# bonuses
#
# 63
# 0:00:00.248000 --> 0:00:00.248000
# given
#
# 64
# 0:00:00.248000 --> 0:00:00.248000
# out
#
# 65
# 0:00:00.248000 --> 0:00:00.248000
# by
#
# 66
# 0:00:00.248000 --> 0:00:00.248000
# online
#
# 67
# 0:00:00.248000 --> 0:00:00.248000
# casinos.
#
# 68
# 0:00:00.248000 --> 0:00:00.248000
# With
#
# 69
# 0:00:00.248000 --> 0:00:00.248000
# each
#
# 70
# 0:00:00.248000 --> 0:00:00.248000
# spin,
#
# 71
# 0:00:00.248000 --> 0:00:00.248000
# you
#
# 72
# 0:00:00.248000 --> 0:00:00.248000
# can
#
# 73
# 0:00:00.248000 --> 0:00:00.248000
# win
#
# 74
# 0:00:00.248000 --> 0:00:00.248000
# anywhere
#
# 75
# 0:00:00.248000 --> 0:00:00.248000
# between
#
# 76
# 0:00:00.248000 --> 0:00:00.248000
# $50
#
# 77
# 0:00:00.248000 --> 0:00:00.248000
# and
#
# 78
# 0:00:00.248000 --> 0:00:00.248000
# $3
#
# 79
# 0:00:00.248000 --> 0:00:00.248000
# million.
#
# 80
# 0:00:00.248000 --> 0:00:00.248000
# And
#
# 81
# 0:00:00.248000 --> 0:00:00.248000
# it's
#
# 82
# 0:00:00.248000 --> 0:00:00.248000
# completely
#
# 83
# 0:00:00.248000 --> 0:00:00.248000
# legal
#
# 84
# 0:00:00.248000 --> 0:00:00.248000
# and
#
# 85
# 0:00:00.248000 --> 0:00:00.248000
# risk-free
#
# 86
# 0:00:00.248000 --> 0:00:00.248000
# for
#
# 87
# 0:00:00.248000 --> 0:00:00.248000
# Canadians.
#
# 88
# 0:00:00.248000 --> 0:00:00.248000
# This
#
# 89
# 0:00:00.248000 --> 0:00:00.248000
# loophole
#
# 90
# 0:00:00.248000 --> 0:00:00.248000
# will
#
# 91
# 0:00:00.248000 --> 0:00:00.248000
# not
#
# 92
# 0:00:00.248000 --> 0:00:00.248000
# last
#
# 93
# 0:00:00.248000 --> 0:00:00.248000
# long.
#
# 94
# 0:00:00.248000 --> 0:00:00.248000
# Click
#
# 95
# 0:00:00.248000 --> 0:00:00.248000
# the
#
# 96
# 0:00:00.248000 --> 0:00:00.248000
# button
#
# 97
# 0:00:00.248000 --> 0:00:00.248000
# below
#
# 98
# 0:00:00.248000 --> 0:00:00.248000
# and
#
# 99
# 0:00:00.248000 --> 0:00:00.248000
# collect
#
# 100
# 0:00:00.248000 --> 0:00:00.248000
# your
#
# 101
# 0:00:00.248000 --> 0:00:00.248000
# free
#
# 102
# 0:00:00.248000 --> 0:00:00.248000
# spins
#
# 103
# 0:00:00.248000 --> 0:00:00.248000
# now.
